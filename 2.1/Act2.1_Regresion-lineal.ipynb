# %% [markdown]
# # Act 2.1 **Regresión Lineal**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("Rio_limpio.csv")

# %% [markdown]
# ## **Generar 4 dataframes (por cada tipo de cuarto)**

# %%
df["room_type"].value_counts()
# Out:
# room_type
# Entire home/apt    31728
# Private room        7483
# Shared room          260
# Hotel room            28
# Name: count, dtype: int64

# %%
entire_home=df[df["room_type"]=="Entire home/apt"]
private_room=df[df["room_type"]=="Private room"]
shared_room=df[df["room_type"]=="Shared room"]
hotel_room=df[df["room_type"]=="Hotel room"]

# %% [markdown]
# ## Regresión Lineal ***Entire home/apt***

# %%
#Eliminar columnas de tipo string
entire_home_num=entire_home.select_dtypes(include=['float64', 'int64','float','int'])



#Mapa de calor

Corr_factors=entire_home_num.corr()
Corr_factors_abosluto=abs(Corr_factors)
corr=abs(entire_home_num.corr())

Corr_factors_abosluto
# Out:
#                                               host_response_rate  \
# host_response_rate                                      1.000000
# host_acceptance_rate                                    0.262927
# host_listings_count                                     0.100480
# host_total_listings_count                               0.092999
# accommodates                                            0.019554
# bathrooms                                               0.046446
# bedrooms                                                0.051577
# beds                                                    0.003213
# price                                                   0.007332
# minimum_nights                                          0.011580
# maximum_nights                                          0.003880
# minimum_minimum_nights                                  0.033494
# maximum_minimum_nights                                  0.091595
# ...

# %%
Heat_map=sns.heatmap(corr, cmap="coolwarm")
Heat_map
# Out:
# <Axes: >

# %% [markdown]
# “host_acceptance_rate vs host_response_rate” : 0.262927
#
# “review_scores_location vs review_scores_cleanliness” : 0.310911
#
# “host_acceptance_rate vs price” : 0.023902
#
# “availability_365 vs number_of_reviews” : 0.156236
#
# “host_acceptance_rate vs number_of_reviews ” : 0.234833
#
# “reviews_per_month vs review_scores_communication” : 0.234737

# %% [markdown]
# ### Modelo matemático mejor correlación

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= entire_home[['review_scores_location', "review_scores_communication"]]
Var_Dep= entire_home['review_scores_cleanliness']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
print(coef_Deter)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
print("Obtenemos un coeficiente más alto que los obtenidos en la regresión simple")
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
# Out:
# 0.23459167196683473
# 0.48434664442611214
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %% [markdown]
# ## Regresión Lineal ***Private room***

# %%
#Eliminar columnas de tipo string
private_room_num=private_room.select_dtypes(include=['float64', 'int64','float','int'])
filtro=private_room[["host_acceptance_rate", "host_response_rate","review_scores_location", "review_scores_cleanliness", "price", 
                    "number_of_reviews", "availability_365", "reviews_per_month", "review_scores_communication"]]


#Mapa de calor

Corr_factors=private_room_num.corr()
Corr_factors_abosluto=abs(Corr_factors)
corr=abs(private_room_num.corr())

Corr_factors_abosluto
# Out:
#                                               host_response_rate  \
# host_response_rate                                      1.000000
# host_acceptance_rate                                    0.171749
# host_listings_count                                     0.088682
# host_total_listings_count                               0.072068
# accommodates                                            0.001045
# bathrooms                                               0.049508
# bedrooms                                                0.036174
# beds                                                    0.028597
# price                                                   0.082469
# minimum_nights                                          0.017816
# maximum_nights                                          0.035910
# minimum_minimum_nights                                  0.004821
# maximum_minimum_nights                                  0.064426
# ...

# %%
Heat_map=sns.heatmap(corr, cmap="coolwarm")
Heat_map
# Out:
# <Axes: >

# %% [markdown]
# “host_acceptance_rate vs host_response_rate” : 0.171749
#
# “review_scores_location vs review_scores_cleanliness” : 0.426432
#
# “host_acceptance_rate vs price” : 0.021871
#
# “availability_365 vs number_of_reviews” : 0.146064
#
# “host_acceptance_rate vs number_of_reviews ” : 0.198942
#
# “reviews_per_month vs review_scores_communication” : 0.422936

# %% [markdown]
# ### Modelo matemático mejor correlación

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= private_room[['review_scores_location', "review_scores_communication"]]
Var_Dep= private_room['review_scores_cleanliness']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
print(coef_Deter)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
print("Obtenemos un coeficiente más alto que los obtenidos en la regresión simple")
# Out:
# 0.29253859498334567
# 0.5408683712173837
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %% [markdown]
# ## Regresión Lineal ***Shared room***

# %%
#Eliminar columnas de tipo string
shared_room_num=shared_room.select_dtypes(include=['float64', 'int64','float','int'])
filtro=shared_room[["host_acceptance_rate", "host_response_rate","review_scores_location", "review_scores_cleanliness", "price", 
                    "number_of_reviews", "availability_365", "reviews_per_month", "review_scores_communication"]]


#Mapa de calor

Corr_factors=shared_room_num.corr()
Corr_factors_abosluto=abs(Corr_factors)
corr=abs(shared_room_num.corr())

Corr_factors_abosluto
# Out:
#                                               host_response_rate  \
# host_response_rate                                      1.000000
# host_acceptance_rate                                    0.284903
# host_listings_count                                     0.103352
# host_total_listings_count                               0.137698
# accommodates                                            0.173577
# bathrooms                                               0.034011
# bedrooms                                                0.166980
# beds                                                    0.135261
# price                                                   0.051001
# minimum_nights                                          0.116761
# maximum_nights                                          0.136832
# minimum_minimum_nights                                  0.101850
# maximum_minimum_nights                                  0.029224
# ...

# %%
Heat_map=sns.heatmap(corr, cmap="coolwarm")
Heat_map
# Out:
# <Axes: >

# %% [markdown]
# “host_acceptance_rate vs host_response_rate” : 0.171749
#
# “review_scores_location vs review_scores_cleanliness” : 0.140702
#
# “host_acceptance_rate vs price” : 0.021871
#
# “availability_365 vs number_of_reviews” : 0.146064
#
# “host_acceptance_rate vs number_of_reviews ” : 0.198942
#
# “reviews_per_month vs review_scores_communication” : 0.42293

# %% [markdown]
# ### Modelo matemático mejor correlación

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= shared_room[['review_scores_cleanliness', "review_scores_communication"]]
Var_Dep= shared_room['reviews_per_month']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
print(coef_Deter)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
print("Obtenemos un coeficiente más alto que los obtenidos en la regresión simple")
# Out:
# 0.1951780868904598
# 0.4417896409949647
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %% [markdown]
# ## Regresión Lineal ***Hotel room***

# %%
#Eliminar columnas de tipo string
hotel_room_num=hotel_room.select_dtypes(include=['float64', 'int64','float','int'])
filtro=hotel_room[["host_acceptance_rate", "host_response_rate","review_scores_location", "review_scores_cleanliness", "price", 
                    "number_of_reviews", "availability_365", "reviews_per_month", "review_scores_communication"]]


#Mapa de calor

Corr_factors=hotel_room_num.corr()
Corr_factors_abosluto=abs(Corr_factors)
corr=abs(hotel_room_num.corr())

Corr_factors_abosluto
# Out:
#                                               host_response_rate  \
# host_response_rate                                      1.000000
# host_acceptance_rate                                    0.366378
# host_listings_count                                     0.227171
# host_total_listings_count                               0.023410
# accommodates                                            0.449548
# bathrooms                                               0.363482
# bedrooms                                                0.108098
# beds                                                    0.533280
# price                                                   0.530157
# minimum_nights                                          0.324708
# maximum_nights                                          0.126374
# minimum_minimum_nights                                  0.287456
# maximum_minimum_nights                                  0.166059
# ...

# %%
Heat_map=sns.heatmap(corr, cmap="coolwarm")
Heat_map
# Out:
# <Axes: >

# %% [markdown]
# “host_acceptance_rate vs host_response_rate” : 0.366378
#
# “review_scores_location vs review_scores_cleanliness” : 0.285361
#
# “host_acceptance_rate vs price” : 0.171029
#
# “availability_365 vs number_of_reviews” : 0.168814
#
# “host_acceptance_rate vs number_of_reviews ” : 0.244364
#
# “reviews_per_month vs review_scores_communication” : 0.614749

# %% [markdown]
# ### Modelo matemático mejor correlación

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= hotel_room[['review_scores_cleanliness', "review_scores_communication", "review_scores_location"]]
Var_Dep= hotel_room['reviews_per_month']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
print(coef_Deter)

#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
print("Obtenemos un coeficiente más alto que los obtenidos en la regresión simple")
# Out:
# 0.4236929798618484
# 0.6509170299368794
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %% [markdown]
# ## Tablas de correlaciones

# %% [markdown]
# ### Entire home/apt

# %%
data = {
    "Variable 1": [
        "host_listings_count",
        "calculated_host_listings_count",
        "host_listings_count",
        "review_scores_rating",
        "review_scores_checkin",
        "bathrooms",
        "review_scores_rating",
        "review_scores_rating",
        "review_scores_rating",
        "accommodates",
    ],
    "Variable 2": [
        "calculated_host_listings_count",
        "calculated_host_listings_count_entire_homes",
        "host_total_listings_count",
        "review_scores_value",
        "review_scores_communication",
        "bedrooms",
        "review_scores_cleanliness",
        "review_scores_communication",
        "review_scores_accuracy",
        "bedrooms",
    ],
    "r": [0.7484, 0.7247, 0.7063, 0.6648, 0.6546, 0.6252, 0.5769, 0.5752, 0.5389, 0.6023],
}

# Crear DataFrame y calcular R²
df = pd.DataFrame(data)
df["R²"] = df["r"] ** 2  # Coeficiente de determinación

# Formatear valores para redondeo 
df["r"] = df["r"].round(4)
df["R²"] = df["R²"].round(4)

df
# Out:
#                        Variable 1  \
# 0             host_listings_count
# 1  calculated_host_listings_count
# 2             host_listings_count
# 3            review_scores_rating
# 4           review_scores_checkin
# 5                       bathrooms
# 6            review_scores_rating
# 7            review_scores_rating
# 8            review_scores_rating
# 9                    accommodates
#
#                                     Variable 2       r      R²
# 0               calculated_host_listings_count  0.7484  0.5601
# 1  calculated_host_listings_count_entire_homes  0.7247  0.5252
# 2                    host_total_listings_count  0.7063  0.4989
# 3                          review_scores_value  0.6648  0.4420
# 4                  review_scores_communication  0.6546  0.4285
# 5                                     bedrooms  0.6252  0.3909
# 6                    review_scores_cleanliness  0.5769  0.3328
# 7                  review_scores_communication  0.5752  0.3309
# ...

# %% [markdown]
# ### Private room

# %%
data = {
    "Variable 1": [
        "host_listings_count",               
        "review_scores_rating",             
        "review_scores_checkin",           
        "review_scores_communication",      
        "host_listings_count",               
        "review_scores_cleanliness",         
        "review_scores_rating",             
        "review_scores_value",               
        "calculated_host_listings_count",   
        "beds"                             
    ],
    "Variable 2": [
        "calculated_host_listings_count",   
        "review_scores_value",              
        "review_scores_communication",     
        "review_scores_checkin",            
        "host_total_listings_count",         
        "review_scores_rating",              
        "review_scores_accuracy",           
        "review_scores_rating",             
        "calculated_host_listings_count_entire_homes",  
        "accommodates"

    ],
    "r": [0.836995, 0.695849, 0.709231, 0.709231, 0.713199, 
          0.608201, 0.594687, 0.695849, 0.422739, 0.494964],
}

# Crear DataFrame y calcular R²
df = pd.DataFrame(data)
df["R²"] = df["r"] ** 2  # Coeficiente de determinación

# Formatear a 4 decimales
df = df.round({"r": 4, "R²": 4})
df
# Out:
#                        Variable 1  \
# 0             host_listings_count
# 1            review_scores_rating
# 2           review_scores_checkin
# 3     review_scores_communication
# 4             host_listings_count
# 5       review_scores_cleanliness
# 6            review_scores_rating
# 7             review_scores_value
# 8  calculated_host_listings_count
# 9                            beds
#
#                                     Variable 2       r      R²
# 0               calculated_host_listings_count  0.8370  0.7006
# 1                          review_scores_value  0.6958  0.4842
# 2                  review_scores_communication  0.7092  0.5030
# 3                        review_scores_checkin  0.7092  0.5030
# 4                    host_total_listings_count  0.7132  0.5087
# 5                         review_scores_rating  0.6082  0.3699
# 6                       review_scores_accuracy  0.5947  0.3537
# 7                         review_scores_rating  0.6958  0.4842
# ...

# %% [markdown]
# ### Shared room

# %%
data = {
    "Variable 1": [
        "host_listings_count",            
        "host_listings_count",            
        "host_total_listings_count",      
        "review_scores_rating",           
        "review_scores_checkin",          
        "review_scores_communication",    
        "review_scores_value",            
        "beds",                           
        "calculated_host_listings_count", 
        "reviews_per_month"               
    ],
    "Variable 2": [
        "host_total_listings_count",        
        "calculated_host_listings_count",   
        "calculated_host_listings_count",   
        "review_scores_value",              
        "review_scores_communication",      
        "review_scores_value",              
        "review_scores_checkin",            
        "accommodates",                     
        "calculated_host_listings_count_entire_homes",  
        "review_scores_checkin"             
    ],
    "r": [0.76264, 0.689201, 0.588094, 0.65253, 0.591261, 
          0.549433, 0.506785, 0.494964, 0.422739, 0.425064],
}

# Crear DataFrame y calcular R² 
df = pd.DataFrame(data)
df["R²"] = df["r"] ** 2  # Coeficiente de determinación

# Formatear a 4 decimales
df = df.round({"r": 4, "R²": 4})
df
# Out:
#                        Variable 1  \
# 0             host_listings_count
# 1             host_listings_count
# 2       host_total_listings_count
# 3            review_scores_rating
# 4           review_scores_checkin
# 5     review_scores_communication
# 6             review_scores_value
# 7                            beds
# 8  calculated_host_listings_count
# 9               reviews_per_month
#
#                                     Variable 2       r      R²
# 0                    host_total_listings_count  0.7626  0.5816
# 1               calculated_host_listings_count  0.6892  0.4750
# 2               calculated_host_listings_count  0.5881  0.3459
# 3                          review_scores_value  0.6525  0.4258
# 4                  review_scores_communication  0.5913  0.3496
# 5                          review_scores_value  0.5494  0.3019
# 6                        review_scores_checkin  0.5068  0.2568
# 7                                 accommodates  0.4950  0.2450
# ...

# %% [markdown]
# ### Hotel room

# %%
data = {
    "Variable 1": [
        "host_total_listings_count",
        "host_listings_count",
        "review_scores_communication",
        "number_of_reviews_ltm",
        "review_scores_checkin",
        "review_scores_location",
        "host_listings_count",
        "calculated_host_listings_count",
        "review_scores_cleanliness",
        "reviews_per_month"
    ],
    "Variable 2": [
        "review_scores_communication",
        "calculated_host_listings_count",
        "review_scores_checkin",
        "reviews_per_month",
        "review_scores_communication",
        "review_scores_communication",
        "host_total_listings_count",
        "host_total_listings_count",
        "reviews_per_month",
        "review_scores_communication"
    ],
    "r": [0.664872, 0.73454, 0.729109, 0.794369, 0.59289, 0.614647, 0.753173, 0.699055, 0.45775, 0.614749],
}

# Crear DataFrame y calcular R² 
df = pd.DataFrame(data)
df["R²"] = df["r"] ** 2 # Coeficiente de determinación

# Formatear a 4 decimales
df = df.round({"r": 4, "R²": 4})
df
# Out:
#                        Variable 1                      Variable 2       r  \
# 0       host_total_listings_count     review_scores_communication  0.6649
# 1             host_listings_count  calculated_host_listings_count  0.7345
# 2     review_scores_communication           review_scores_checkin  0.7291
# 3           number_of_reviews_ltm               reviews_per_month  0.7944
# 4           review_scores_checkin     review_scores_communication  0.5929
# 5          review_scores_location     review_scores_communication  0.6146
# 6             host_listings_count       host_total_listings_count  0.7532
# 7  calculated_host_listings_count       host_total_listings_count  0.6991
# 8       review_scores_cleanliness               reviews_per_month  0.4578
# 9               reviews_per_month     review_scores_communication  0.6147
#
#        R²
# 0  0.4421
# 1  0.5395
# 2  0.5316
# 3  0.6310
# 4  0.3515
# 5  0.3778
# 6  0.5673
# 7  0.4887
# 8  0.2095
# 9  0.3779

# %% [markdown]
# ## Crear el mejor modelo de regression lineal multiple para cada variable cuantitativa:
#  (host_id, host_acceptance_rate, host_is_superhost, host_total_listings_count, room_type, accommodates, bedrooms, Price, review_scores_value y reviews_per_month)

# %%
rio=pd.read_csv("Rio_limpio.csv",index_col=0)


rio['host_is_superhost_num'] = rio['host_is_superhost']
rio['host_is_superhost_num'] = rio['host_is_superhost_num'].str.replace('f', "0")
rio['host_is_superhost_num'] = rio['host_is_superhost_num'].str.replace('t', "1")
rio['host_is_superhost_num'] = rio['host_is_superhost_num'].str.replace('Sin regis1ro', "2")

rio['host_is_superhost_num'] = rio['host_is_superhost_num'].astype(int)
#_______
frecuencias = rio['room_type'].value_counts()

# 2. Crear un diccionario de mapeo: nombre -> número según frecuencia
mapeo_numeros = {nombre: i+1 for i, (nombre, count) in enumerate(frecuencias.items())}

# 3. Aplicar el reemplazo en la columna
rio['room_type_num'] = rio['room_type'].map(mapeo_numeros)

rio['room_type_num'] = rio['room_type_num'].astype(int)
#_______


#Eliminar columnas de tipo string
dataframe_numerico=rio.select_dtypes(include=['float64', 'int64','float','int'])


#Mapa de calor
Corr_factors=dataframe_numerico.corr()
Corr_factors_abosluto=abs(Corr_factors)
corr=abs(hotel_room_num.corr())

Corr_factors_abosluto
# Out:
#                                               host_response_rate  \
# host_response_rate                                      1.000000
# host_acceptance_rate                                    0.248764
# host_listings_count                                     0.091556
# host_total_listings_count                               0.083070
# accommodates                                            0.019267
# bathrooms                                               0.035701
# bedrooms                                                0.029692
# beds                                                    0.011382
# price                                                   0.005277
# minimum_nights                                          0.007434
# maximum_nights                                          0.012527
# minimum_minimum_nights                                  0.014875
# maximum_minimum_nights                                  0.101972
# ...

# %%
Heat_map=sns.heatmap(corr, cmap="coolwarm")
Heat_map
# Out:
# <Axes: >

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['host_acceptance_rate', "calculated_host_listings_count_entire_homes"]]
Var_Dep= rio['host_response_rate']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.06826532529408191
# 0.26127633894802244
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['host_response_rate', "number_of_reviews_ltm"]]
Var_Dep= rio['host_acceptance_rate']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.12281383224113585
# 0.3504480449954541
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['number_of_reviews_ltm', "host_acceptance_rate"]]
Var_Dep= rio['host_is_superhost_num']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.16530751233777063
# 0.4065802655537657
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['host_listings_count', "host_listings_count"]]
Var_Dep= rio['host_total_listings_count']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.5061532620951169
# 0.7114444898199135
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['calculated_host_listings_count_private_rooms', "accommodates"]]
Var_Dep= rio['room_type_num']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.43860565662865425
# 0.6622730982220659
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['bathrooms', "beds"]]
Var_Dep= rio['accommodates']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.41099228568700374
# 0.6410868004311145
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['bathrooms', "accommodates"]]
Var_Dep= rio['bedrooms']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.4984551526721821
# 0.7060135640851258
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['bedrooms', "accommodates"]]
Var_Dep= rio['price']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.16810144301055863
# 0.41000175976519737
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['review_scores_rating', "review_scores_accuracy"]]
Var_Dep= rio['review_scores_value']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.5036542894090481
# 0.7096860498904062
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= rio[['number_of_reviews_ltm', "number_of_reviews_l30d"]]
Var_Dep= rio['reviews_per_month']

#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__

#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Correl=np.sqrt(coef_Deter)
print(coef_Correl)
# Out:
# 0.18553543744743073
# 0.43073824702182034
# Obtenemos un coeficiente más alto que los obtenidos en la regresión simple
